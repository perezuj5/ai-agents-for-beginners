# %% [markdown]
# # Lesson 03 - Agentic Design Patterns
#
# In this lesson, we explore three foundational design patterns for building effective AI agents:
#
# 1. **Clear Agent Instructions** — Crafting precise, role-defining prompts that guide agent behavior
# 2. **Structured Output with Pydantic Models** — Ensuring agents return predictable, validated data
# 3. **Single Responsibility Agents** — Designing focused agents that each do one thing well
#
# We'll apply each pattern to a **travel destination recommender** scenario, progressively building a system that can suggest destinations, check availability, and handle logistics.

# %% [markdown]
# ## Setup

# %%
# %pip install agent-framework azure-ai-projects azure-identity pydantic --quiet

# %%
import logging
logging.getLogger("agent_framework.azure").setLevel(logging.ERROR)

import os
import asyncio
from typing import Annotated
from pydantic import BaseModel
from agent_framework import tool
from agent_framework.azure import AzureAIProjectAgentProvider
from azure.identity import AzureCliCredential

# %% [markdown]
# ## Pattern 1: Clear Agent Instructions
#
# The most impactful pattern is also the simplest: writing clear, detailed instructions for your agent.
#
# Good instructions define:
# - **Who** the agent is (persona and tone)
# - **What** it should do (step-by-step responsibilities)
# - **How** it should behave (constraints and style)
#
# Below, we create a travel concierge agent with explicit instructions that shape every response it produces.

# %%
provider = AzureAIProjectAgentProvider(credential=AzureCliCredential())

agent = await provider.create_agent(
    name="TravelConcierge",
    instructions="""You are a luxury travel concierge named Alex. Your role is to:
1. Understand the traveler's preferences (budget, climate, activities)
2. Check destination availability before making recommendations
3. Provide detailed, personalized travel suggestions
4. Always mention visa requirements and best travel seasons
Be warm, professional, and enthusiastic about travel.""",
)

response = await agent.run(
    "I'd love a week-long vacation somewhere with great food and history. Budget around $2500."
)
print(response)
# Out:
# Thank you for sharing that, and what a wonderful combination—great food and rich history make for an incredible travel experience! With a $2,500 budget for a week-long getaway, let me provide some suggestions tailored to your preferences. Could you let me know a bit more about your climate preference (warm, mild, or cool) and where you're traveling from so I can consider flight costs and visa requirements for you?
#
# Looking forward to curating the perfect vacation for you! ✈️🍷

# %% [markdown]
# ## Pattern 2: Structured Output with Pydantic Models
#
# Free-form text is useful for conversation, but downstream systems need structured data.
# By pairing **Pydantic models** with a **tool function**, we can:
#
# - Define an exact schema for the agent's output
# - Validate responses automatically
# - Integrate agent results into application logic reliably
#
# We also introduce a tool that returns destination details so the agent grounds its recommendations in real data.

# %%
class DestinationRecommendation(BaseModel):
    destination: str
    available: bool
    best_season: str
    highlights: list[str]
    estimated_budget_usd: int


class TravelRecommendations(BaseModel):
    recommendations: list[DestinationRecommendation]
    personalized_note: str


@tool(approval_mode="never_require")
def get_destination_details(destination: Annotated[str, "The destination to look up"]) -> str:
    """Get details about a vacation destination."""
    details = {
        "Barcelona": "Available. Best: May-Jun. Beach, architecture, nightlife. ~$2000/week",
        "Tokyo": "Available. Best: Mar-Apr. Culture, food, technology. ~$2500/week",
        "Cape Town": "Not available. Best: Nov-Mar. Nature, wine, adventure. ~$1800/week",
    }
    return details.get(destination, f"{destination}: No information available.")


structured_agent = await provider.create_agent(
    name="StructuredTravelExpert",
    instructions="You are a travel expert. Recommend destinations based on traveler preferences. Use the get_destination_details tool.",
    tools=[get_destination_details],
)

response = await structured_agent.run(
    "Recommend 3 destinations for a culture-loving traveler with a $2500 budget"
)

if response:
    print(response)

response = await structured_agent.run(
    "I would like to visit Cape Town. Can you provide details?"
)

if response:
    print(response)
# Out:
# Here are three culturally rich destinations perfectly suited for a $2500 budget:
#
# 1. **Kyoto, Japan**
#    Renowned for its well-preserved ancient temples, traditional tea houses, and stunning bamboo forests, Kyoto is a history-lover's dream. Explore Gion, Kyoto's geisha district, and visit iconic sites like Fushimi Inari Shrine.
#
# 2. **Rome, Italy**
#    Dive into the heart of Western culture with a visit to Rome. Enjoy its architectural masterpieces such as the Colosseum, Roman Forum, Vatican City, and countless piazzas filled with rich history and art.
#
# 3. **Istanbul, Turkey**
#    Experience the blend of East and West in Istanbul. Visit the Hagia Sophia, Blue Mosque, and Topkapi Palace while enjoying the vibrant bazaars and traditional Turkish tea.
#
# Each of these destinations offers deep cultural experiences and can comfortably be explored within a $2500 budget.
# Cape Town is a stunning destination known for its breathtaking nature, adventure activities, and excellent wine. The best time to visit is between November and March, when the weather is warm and ideal for outdoor exploration. For a week-long trip, you can expect to spend around $1,800 on average. Let me know if you'd like help planning your visit!

# %% [markdown]
# ## Pattern 3: Single Responsibility Agents
#
# Complex tasks benefit from splitting work across multiple focused agents, each with a single responsibility:
#
# - A **Destination Expert** that knows about places and availability
# - A **Logistics Planner** that handles flights, hotels, and itineraries
#
# This mirrors the software engineering principle of *separation of concerns* — each agent is easier to test, maintain, and improve independently.

# %%
destination_agent = await provider.create_agent(
    name="DestinationExpert",
    tools=[get_destination_details],
    instructions="""You are a destination research specialist. Your only job is to:
1. Evaluate destinations based on traveler preferences
2. Check availability using the provided tool
3. Return a short ranked list with pros/cons
Do NOT discuss flights, hotels, or logistics — another agent handles that.""",
)

logistics_agent = await provider.create_agent(
    name="LogisticsPlanner",
    instructions="""You are a travel logistics planner. Your only job is to:
1. Create a day-by-day itinerary for the chosen destination
2. Suggest flight and hotel options within the stated budget
3. Note visa requirements and travel insurance recommendations
Do NOT recommend destinations — another agent handles that.""",
)

# Step 1: Destination Expert picks the best options
dest_response = await destination_agent.run(
    "I want a week of culture and food for under $2500. Where should I go?"
)
print("=== Destination Expert ===")
print(dest_response)

# Step 2: Logistics Planner builds the trip plan
logistics_response = await logistics_agent.run(
    f"Plan a week-long trip based on this recommendation:\n{dest_response}"
)
print("\n=== Logistics Planner ===")
print(logistics_response)
# Out:
# === Destination Expert ===
# Based on traveler preferences for culture and food under $2,500, here’s a ranked list to consider:
#
# ### 1. Kyoto, Japan
# **Pros:**
# - Renowned for its rich cultural history, including temples, shrines, and traditional geisha districts.
# - Exceptional food scene with local specialties like kaiseki and ramen.
# **Cons:**
# - Certain activities (tea ceremonies, museum entries) may be pricey.
#
# ### 2. Istanbul, Turkey
# **Pros:**
# - A blend of Eastern and Western culture with iconic landmarks (Hagia Sophia, Grand Bazaar).
# - Affordable and diverse food like kebabs, mezze, and baklava.
# **Cons:**
# - Some tourist areas can be overly crowded and tourist-focused.
#
# ### 3. Barcelona, Spain
# **Pros:**
# - Vibrant cultural scene, including architecture by Gaudí and art museums.
# - Famous cuisine (tapas, paella) and lively local markets.
# **Cons:**
# - May feel expensive in restaurants or at cultural landmarks.
#
# Let me know if you'd like a deeper comparison or further options!
#
# === Logistics Planner ===
# Let's proceed with **Kyoto, Japan**, based on its rich cultural and culinary experiences matching with the traveler’s budget of $2,500. Below is a 7-day itinerary including flight and hotel suggestions, visa requirements, and travel insurance recommendations.
#
# ---
#
# ### Total Budget: $2,500
# *Breakdown*: Estimated cost for flights: ~$900, accommodation: ~$600, daily expenses (food, activities, transportation): ~$700, travel insurance: ~$50, miscellaneous: ~250.
#
# ---
#
# ## 7-Day Kyoto, Japan Itinerary
#
# ### Day 1: Arrival in Kyoto
# - **Morning**: Land at Kansai International Airport in Osaka and take the JR Haruka Express train to Kyoto (~75 minutes).
# - **Afternoon**: Check into your hotel and freshen up.
# - **Evening**: Stroll through the **Gion District**, famous for its historic wooden houses and the possibility of spotting geishas.
# - **Meals**: Enjoy Kyoto-style ramen at a casual eatery.
#
# **Hotel Suggestion:**
# - **The Millennials Kyoto** (~$80/night)
#   *A stylish, budget-friendly option featuring capsule-style pods and modern amenities.*
#
# ---
#
# ### Day 2: Explore Eastern Kyoto
# - **Morning**: Start at the **Kiyomizu-dera Temple**, a UNESCO World Heritage Site, and wander the charming Sannenzaka and Ninenzaka streets. Visit pottery and tea shops.
# - **Afternoon**: Head to **Yasaka Shrine** and enjoy green tea-flavored desserts at nearby shops.
# - **Evening**: Attend a traditional **tea ceremony experience** ($30–$50 per person).
# - **Meals**: Sample kaiseki cuisine at a mid-range traditional restaurant, like Hyotei Bento (~$50).
#
# ---
#
# ### Day 3: Arashiyama & Bamboo Forest
# - **Morning**: Take the train to **Arashiyama** and explore the **Bamboo Grove**, **Togetsukyo Bridge**, and **Tenryu-ji Temple** (another UNESCO site).
# - **Afternoon**: Cross the Hozugawa River and visit the **Iwatayama Monkey Park** (~$5 entrance fee).
# - **Evening**: Relax in an outdoor onsen (hot spring) near Arashiyama ($10–$20).
# - **Meals**: Try a tofu-based meal at a riverside restaurant in Arashiyama, such as Saga Tofu Ine.
#
# ---
#
# ### Day 4: Day Trip to Nara
# - **Morning**: Take the JR train (~1 hour) to **Nara** and visit the **Todai-ji Temple**, home to the massive Great Buddha statue.
# - **Afternoon**: Stroll around **Nara Park** to see the free-roaming deer and visit **Kasuga-taisha Shrine**. Return to Kyoto by evening.
# - **Meals**: Enjoy sushi or affordable lunch sets in Nara before returning.
#
# ---
#
# ### Day 5: Fushimi Inari & South Kyoto
# - **Morning**: Climb the famous **Fushimi Inari Taisha** shrine, known for its thousands of red torii gates. Take a leisurely hike to the summit if time allows.
# - **Afternoon**: Stop by Tofuku-ji Temple or the nearby sake breweries in Fushimi for tasting tours.
# - **Evening**: Head back to central Kyoto and unwind.
# - **Meals**: Try Kyoto’s “obanzai” (traditional small dishes) at a cozy eatery like Ganko Sushi & Obanzai.
#
# ---
#
# ### Day 6: Nishiki Market, Cultural Activities & Free Time
# - **Morning**: Visit **Nishiki Market**, a foodie haven filled with snacks, pickles, seafood, and sweets. Take a Japanese cooking class afterward (~$50–$100).
# - **Afternoon**: Enjoy free time exploring **Kyoto Imperial Palace** or **Nijo Castle**.
# - **Evening**: Have a farewell izakaya dining experience.
# - **Meals**: Savor matcha-based desserts or parfaits at Tsujiri in Nishiki.
#
# ---
#
# ### Day 7: Departure
# - **Morning**: Last-minute shopping for souvenirs at Kyoto Station or Aeon Mall Kyoto.
# - **Afternoon**: Return to Kansai International Airport.
# - **Meals**: Enjoy a quick train station bento box or sushi set meal before leaving Japan.
#
# ---
#
# ## Flight Options
# Flights based on departure from Los Angeles (LAX) or similar U.S. city:
# - **Japan Airlines** or **ANA**: ~$850–$950 round-trip (economy).
# - Alternative Budget Airlines (e.g., Zipair): ~$600–$800 round-trip (economy, fewer amenities).
#
# ---
#
# ## Accommodation Options (6 Nights Total)
# **1. The Millennials Kyoto** (~$80/night; ~$480 total).
# - Capsule hotel with modern amenities and a shared lounge.
#
# **2. Hotel Mystays Kyoto Shijo** (~$100/night; ~$600 total).
# - A mid-range option with comfortable private rooms and convenient access to public transit.
#
# ---
#
# ## Visa Requirements:
# - **U.S. Citizens**: Japan offers visa-free entry for up to 90 days for U.S. passport holders. Ensure your passport is valid for the duration of your stay.
# - Update: Check local requirements as they may change (e.g., post-pandemic procedures like vaccine documentation).
#
# ---
#
# ## Travel Insurance:
# - Recommended providers: **World Nomads** or **Allianz Travel**.
# - Estimated cost: ~$50 for a 7-day trip including emergency medical coverage, trip delays, or cancellations.
#
# ---
#
# Let me know if you’d like adjustments to this itinerary!

# %% [markdown]
# ## Summary
#
# In this lesson we applied three agentic design patterns to a travel recommender scenario:
#
# | Pattern | Key Idea | Benefit |
# |---|---|---|
# | **Clear Instructions** | Define persona, responsibilities, and constraints up front | Consistent, on-brand agent behavior |
# | **Structured Output** | Use Pydantic models as the response format | Validated, machine-readable results |
# | **Single Responsibility** | Give each agent one focused job | Easier to test, maintain, and compose |
#
# These patterns compose naturally — you can combine clear instructions with structured output inside a single-responsibility agent to build robust, production-ready systems.
